# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df['Rings'].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# Label Encoder - Converting sex column into numerical data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
sex_encoding = le.fit_transform(df['Sex'])
sex_encoding.dtype
# Out:
# dtype('int32')

# %%
pd.Series(sex_encoding)
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       1
#        ..
# 4172    0
# 4173    2
# 4174    2
# 4175    0
# 4176    2
# Length: 4177, dtype: int32

# %%
df['Sex'] = sex_encoding
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix

import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(20,15), facecolor='yellow')
plotnumber = 1

for column in df:
    if plotnumber <= 9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
        plotnumber += 1
plt.tight_layout()

# %%
df.hist(bins=50, figsize=(15,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df.drop('Rings', axis=1)
y = df['Rings']

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
Xscaled = scaler.fit_transform(x)
Xscaled
# Out:
# array([[ 1.15198011, -0.57455813, -0.43214879, ..., -0.60768536,
#         -0.72621157, -0.63821689],
#        [ 1.15198011, -1.44898585, -1.439929  , ..., -1.17090984,
#         -1.20522124, -1.21298732],
#        [-1.28068972,  0.05003309,  0.12213032, ..., -0.4634999 ,
#         -0.35668983, -0.20713907],
#        ...,
#        [ 1.15198011,  0.6329849 ,  0.67640943, ...,  0.74855917,
#          0.97541324,  0.49695471],
#        [-1.28068972,  0.84118198,  0.77718745, ...,  0.77334105,
#          0.73362741,  0.41073914],
#        [ 1.15198011,  1.54905203,  1.48263359, ...,  2.64099341,
#          1.78744868,  1.84048058]])

# %%
x = pd.DataFrame(Xscaled, columns= x.columns)
x
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.151980 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1     1.151980 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2    -1.280690  0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3     1.151980 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4    -0.064355 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
# ...        ...       ...       ...       ...           ...             ...
# 4172 -1.280690  0.341509  0.424464  0.609334      0.118813        0.047908
# 4173  1.151980  0.549706  0.323686 -0.107991      0.279929        0.358808
# 4174  1.151980  0.632985  0.676409  1.565767      0.708212        0.748559
# 4175 -1.280690  0.841182  0.777187  0.250672      0.541998        0.773341
# 4176  1.151980  1.549052  1.482634  1.326659      2.283681        2.640993
#
#       Viscera weight  Shell weight
# ...

# %%
plt.figure(figsize=(15,10), facecolor='yellow')
plotnumber = 1

for column in x:
    if plotnumber <= 8:
        plt.subplot(4,2,plotnumber)
        plt.scatter(x[column], y)
        plt.xlabel(column, fontsize=20)
        plt.ylabel('Rings', fontsize=20)
        plotnumber += 1
plt.tight_layout()

# %%
x
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.151980 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1     1.151980 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2    -1.280690  0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3     1.151980 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4    -0.064355 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
# ...        ...       ...       ...       ...           ...             ...
# 4172 -1.280690  0.341509  0.424464  0.609334      0.118813        0.047908
# 4173  1.151980  0.549706  0.323686 -0.107991      0.279929        0.358808
# 4174  1.151980  0.632985  0.676409  1.565767      0.708212        0.748559
# 4175 -1.280690  0.841182  0.777187  0.250672      0.541998        0.773341
# 4176  1.151980  1.549052  1.482634  1.326659      2.283681        2.640993
#
#       Viscera weight  Shell weight
# ...

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %% [markdown]
# replacing scaled values in main dataframe to check the correlation

# %%
df = pd.concat([x,y], axis=1)

# %%
df
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.151980 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1     1.151980 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2    -1.280690  0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3     1.151980 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4    -0.064355 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
# ...        ...       ...       ...       ...           ...             ...
# 4172 -1.280690  0.341509  0.424464  0.609334      0.118813        0.047908
# 4173  1.151980  0.549706  0.323686 -0.107991      0.279929        0.358808
# 4174  1.151980  0.632985  0.676409  1.565767      0.708212        0.748559
# 4175 -1.280690  0.841182  0.777187  0.250672      0.541998        0.773341
# 4176  1.151980  1.549052  1.482634  1.326659      2.283681        2.640993
#
#       Viscera weight  Shell weight  Rings
# ...

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(15,7))

sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor='black', fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see, there is no realtion between sex and the age, so we can drop the Sex Column

# %%
df=df.drop(columns=['Sex'])

# %%
df
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1    -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2     0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3    -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4    -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
# ...        ...       ...       ...           ...             ...
# 4172  0.341509  0.424464  0.609334      0.118813        0.047908
# 4173  0.549706  0.323686 -0.107991      0.279929        0.358808
# 4174  0.632985  0.676409  1.565767      0.708212        0.748559
# 4175  0.841182  0.777187  0.250672      0.541998        0.773341
# 4176  1.549052  1.482634  1.326659      2.283681        2.640993
#
#       Viscera weight  Shell weight  Rings
# 0          -0.726212     -0.638217     15
# 1          -1.205221     -1.212987      7
# 2          -0.356690     -0.207139      9
# ...

# %% [markdown]
# Checking the skewness

# %%
df.skew().sort_values(ascending = False)
# Out:
# Height            3.128817
# Rings             1.114102
# Shucked weight    0.719098
# Shell weight      0.620927
# Viscera weight    0.591852
# Whole weight      0.530959
# Diameter         -0.609198
# Length           -0.639873
# dtype: float64

# %% [markdown]
# Using Power_transform

# %%
from sklearn.preprocessing import power_transform, PowerTransformer

# %%
df_new = power_transform(df)

# %%
df_new
# Out:
# array([[-0.6849009 , -0.55736413, -1.11280702, ..., -0.70123868,
#         -0.59624727,  1.48235844],
#        [-1.36298086, -1.35655361, -1.25247488, ..., -1.33365527,
#         -1.33155026, -0.94913462],
#        [-0.09585381, -0.01582614, -0.05371504, ..., -0.25568006,
#         -0.09871491, -0.17607507],
#        ...,
#        [ 0.58341456,  0.63811557,  1.51578957, ...,  1.00490612,
#          0.59434636, -0.17607507],
#        [ 0.85408745,  0.76783818,  0.30920709, ...,  0.80771966,
#          0.51655243,  0.15690844],
#        [ 1.86775844,  1.75575341,  1.30665302, ...,  1.60944667,
#          1.6604585 ,  0.74460653]])

# %%
df = pd.DataFrame(df_new, columns=df.columns)
df
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.684901 -0.557364 -1.112807     -0.599328       -0.552928
# 1    -1.362981 -1.356554 -1.252475     -1.344919       -1.312173
# 2    -0.095854 -0.015826 -0.053715     -0.213843       -0.374494
# 3    -0.789979 -0.557364 -0.307340     -0.594429       -0.604353
# 4    -1.479784 -1.428218 -1.535804     -1.400633       -1.376867
# ...        ...       ...       ...           ...             ...
# 4172  0.228312  0.327789  0.654101      0.236269        0.197169
# 4173  0.479017  0.209585 -0.053715      0.391302        0.495607
# 4174  0.583415  0.638116  1.515790      0.775196        0.831931
# 4175  0.854087  0.767838  0.309207      0.630453        0.852197
# 4176  1.867758  1.755753  1.306653      1.975682        2.144781
#
#       Viscera weight  Shell weight     Rings
# 0          -0.701239     -0.596247  1.482358
# 1          -1.333655     -1.331550 -0.949135
# 2          -0.255680     -0.098715 -0.176075
# ...

# %%
df.skew().sort_values(ascending = False)
# Out:
# Height            0.617717
# Shucked weight    0.074087
# Shell weight      0.070536
# Viscera weight    0.068330
# Whole weight      0.066262
# Rings             0.004429
# Length           -0.020964
# Diameter         -0.021702
# dtype: float64

# %% [markdown]
# to check the Outliers

# %%
plt.figure(figsize=(20,20))
y=1

for column in df:
    if y <= 8:
        plt.subplot(4,2,y)
        sns.boxplot(data = df[column])
        plt.xlabel(column, fontsize=20)
        y += 1
        
plt.show()

# %% [markdown]
# checking and Removing outliers using zscore

# %%
from scipy.stats import zscore

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %%
zs = zscore(df)
zs
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.684901 -0.557364 -1.112807     -0.599328       -0.552928
# 1    -1.362981 -1.356554 -1.252475     -1.344919       -1.312173
# 2    -0.095854 -0.015826 -0.053715     -0.213843       -0.374494
# 3    -0.789979 -0.557364 -0.307340     -0.594429       -0.604353
# 4    -1.479784 -1.428218 -1.535804     -1.400633       -1.376867
# ...        ...       ...       ...           ...             ...
# 4172  0.228312  0.327789  0.654101      0.236269        0.197169
# 4173  0.479017  0.209585 -0.053715      0.391302        0.495607
# 4174  0.583415  0.638116  1.515790      0.775196        0.831931
# 4175  0.854087  0.767838  0.309207      0.630453        0.852197
# 4176  1.867758  1.755753  1.306653      1.975682        2.144781
#
#       Viscera weight  Shell weight     Rings
# 0          -0.701239     -0.596247  1.482358
# 1          -1.333655     -1.331550 -0.949135
# 2          -0.255680     -0.098715 -0.176075
# ...

# %%
abs_zs = np.abs(zs)
abs_zs
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     0.684901  0.557364  1.112807      0.599328        0.552928
# 1     1.362981  1.356554  1.252475      1.344919        1.312173
# 2     0.095854  0.015826  0.053715      0.213843        0.374494
# 3     0.789979  0.557364  0.307340      0.594429        0.604353
# 4     1.479784  1.428218  1.535804      1.400633        1.376867
# ...        ...       ...       ...           ...             ...
# 4172  0.228312  0.327789  0.654101      0.236269        0.197169
# 4173  0.479017  0.209585  0.053715      0.391302        0.495607
# 4174  0.583415  0.638116  1.515790      0.775196        0.831931
# 4175  0.854087  0.767838  0.309207      0.630453        0.852197
# 4176  1.867758  1.755753  1.306653      1.975682        2.144781
#
#       Viscera weight  Shell weight     Rings
# 0           0.701239      0.596247  1.482358
# 1           1.333655      1.331550  0.949135
# 2           0.255680      0.098715  0.176075
# ...

# %%
filtering_entry = (abs_zs < 3).all(axis=1)

# %%
filtering_entry.sum().sum()
# Out:
# 4129

# %%
df = df[filtering_entry]
df
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.684901 -0.557364 -1.112807     -0.599328       -0.552928
# 1    -1.362981 -1.356554 -1.252475     -1.344919       -1.312173
# 2    -0.095854 -0.015826 -0.053715     -0.213843       -0.374494
# 3    -0.789979 -0.557364 -0.307340     -0.594429       -0.604353
# 4    -1.479784 -1.428218 -1.535804     -1.400633       -1.376867
# ...        ...       ...       ...           ...             ...
# 4172  0.228312  0.327789  0.654101      0.236269        0.197169
# 4173  0.479017  0.209585 -0.053715      0.391302        0.495607
# 4174  0.583415  0.638116  1.515790      0.775196        0.831931
# 4175  0.854087  0.767838  0.309207      0.630453        0.852197
# 4176  1.867758  1.755753  1.306653      1.975682        2.144781
#
#       Viscera weight  Shell weight     Rings
# 0          -0.701239     -0.596247  1.482358
# 1          -1.333655     -1.331550 -0.949135
# 2          -0.255680     -0.098715 -0.176075
# ...

# %% [markdown]
# Checking outliers after removal using zscore

# %%
plt.figure(figsize=(20,20))
y=1

for column in df:
    if y <= 8:
        plt.subplot(4,2,y)
        sns.boxplot(data = df[column])
        plt.xlabel(column, fontsize=20)
        y += 1
        
plt.show()

# %% [markdown]
# Checking Normal Distribution after removing skewness and outliers

# %%
plt.figure(figsize=(20,15), facecolor='yellow')
plotnumber = 1

for column in df:
    if plotnumber <= 8:
        ax=plt.subplot(4,2,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
        plotnumber += 1
plt.tight_layout()

# %% [markdown]
# Preprocessing is done, we can train the model now

# %%
x = df.drop('Rings', axis=1)
y = df['Rings']

# %%
x
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.684901 -0.557364 -1.112807     -0.599328       -0.552928
# 1    -1.362981 -1.356554 -1.252475     -1.344919       -1.312173
# 2    -0.095854 -0.015826 -0.053715     -0.213843       -0.374494
# 3    -0.789979 -0.557364 -0.307340     -0.594429       -0.604353
# 4    -1.479784 -1.428218 -1.535804     -1.400633       -1.376867
# ...        ...       ...       ...           ...             ...
# 4172  0.228312  0.327789  0.654101      0.236269        0.197169
# 4173  0.479017  0.209585 -0.053715      0.391302        0.495607
# 4174  0.583415  0.638116  1.515790      0.775196        0.831931
# 4175  0.854087  0.767838  0.309207      0.630453        0.852197
# 4176  1.867758  1.755753  1.306653      1.975682        2.144781
#
#       Viscera weight  Shell weight
# 0          -0.701239     -0.596247
# 1          -1.333655     -1.331550
# 2          -0.255680     -0.098715
# 3          -0.553907     -0.552875
# ...

# %%
y
# Out:
# 0       1.482358
# 1      -0.949135
# 2      -0.176075
# 3       0.156908
# 4      -0.949135
#           ...
# 4172    0.462368
# 4173    0.156908
# 4174   -0.176075
# 4175    0.156908
# 4176    0.744607
# Name: Rings, Length: 4129, dtype: float64

# %% [markdown]
# # Liner Regression

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
r2 = r2_score
lr=LinearRegression()

# %%
maxScore = 0
maxRS = 0

for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75, random_state=i)
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    scr=r2(y_test, y_pred)
    print('accuracy', scr, 'random state',i)
    
    
    if scr>maxScore:
        maxScore = scr
        maxRS = i
        print('Max Accuracy', maxScore, 'Max Random State', maxRS)
# Out:
# accuracy 0.5717260752876236 random state 1
# Max Accuracy 0.5717260752876236 Max Random State 1
# accuracy 0.5629059115934857 random state 2
# accuracy 0.5682889956731785 random state 3
# accuracy 0.5451215362528321 random state 4
# accuracy 0.5744693006701149 random state 5
# Max Accuracy 0.5744693006701149 Max Random State 5
# accuracy 0.5594899355858937 random state 6
# accuracy 0.5689405482769183 random state 7
# accuracy 0.5304696691683358 random state 8
# accuracy 0.5616568960237149 random state 9
# accuracy 0.5801564922775665 random state 10
# Max Accuracy 0.5801564922775665 Max Random State 10
# accuracy 0.5818274074706624 random state 11
# Max Accuracy 0.5818274074706624 Max Random State 11
# accuracy 0.5681627147741929 random state 12
# accuracy 0.5424988084565358 random state 13
# accuracy 0.5565100622452162 random state 14
# accuracy 0.5818336933712893 random state 15
# Max Accuracy 0.5818336933712893 Max Random State 15
# accuracy 0.5599304519423628 random state 16
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75, random_state=101)

# %%
y_pred = lr.predict(x_test)

# %%
R2_Score = r2(y_test, y_pred)
R2_Score
# Out:
# 0.6139100667983157

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
maxScore = 0
maxRS = 0

for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75, random_state=i)
    rf.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    scr=r2(y_test, y_pred)
    print('accuracy', scr, 'random state',i)
    
    
    if scr>maxScore:
        maxScore = scr
        maxRS = i
        print('Max Accuracy', maxScore, 'Max Random State', maxRS)
# Out:
# accuracy 0.5728384399799622 random state 1
# Max Accuracy 0.5728384399799622 Max Random State 1
# accuracy 0.5642902688438403 random state 2
# accuracy 0.5706119762619518 random state 3
# accuracy 0.5463894711071815 random state 4
# accuracy 0.5755071593301246 random state 5
# Max Accuracy 0.5755071593301246 Max Random State 5
# accuracy 0.5619339871127589 random state 6
# accuracy 0.5718973240610203 random state 7
# accuracy 0.5334415968615356 random state 8
# accuracy 0.5667149381956611 random state 9
# accuracy 0.5830214256623316 random state 10
# Max Accuracy 0.5830214256623316 Max Random State 10
# accuracy 0.5833379891719419 random state 11
# Max Accuracy 0.5833379891719419 Max Random State 11
# accuracy 0.5734896841861037 random state 12
# accuracy 0.5448014321410626 random state 13
# accuracy 0.557737314994351 random state 14
# accuracy 0.5873526904913762 random state 15
# Max Accuracy 0.5873526904913762 Max Random State 15
# accuracy 0.5615459573404896 random state 16
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75, random_state=101)

# %% [markdown]
# We are getting same R2 Score in Random Forest Regressor as compared to Liner Regression

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Rings")
plt.show()

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.9494118027251319

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.4356541827882687

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1.198187874579053

# %% [markdown]
# Regularization

# %%
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %%
lasscv = LassoCV(alphas=None, max_iter=100, normalize=True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha = lasscv.alpha_
alpha
# Out:
# 1.1564871634826956e-05

# %%
lasso_reg = Lasso(aplha)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=1.1727915555859457e-05)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# 0.6074578045669616

# %%
ridgecv = RidgeCV(alphas=np.arange(0.001,0.1,0.01), normalize=True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.001

# %%
ridgr_model = Ridge(alpha=ridgecv.alpha_)
ridgr_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.001)

# %%
ridgr_model.score(x_test,y_test)
# Out:
# 0.6075013447481182
